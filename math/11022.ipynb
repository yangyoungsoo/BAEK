# %%
T = int(input())

for i in range(T):
    A,B = map(int, input().split())
    print(f"Case #{i+1}: {A} + {B} = {A+B}")
# Out:
# Case #1: 1 + 1 = 2
# Case #2: 2 + 3 = 5
# Case #3: 3 + 4 = 7
# Case #4: 9 + 8 = 17
# Case #5: 5 + 2 = 7
